# %% [markdown]
# # Plotting a model figure

# %%
import tensorflow as tf

# %%
input = tf.keras.Input(shape=(100,), dtype="int32", name="input")
x = tf.keras.layers.Embedding(
    output_dim=512,
    input_dim=10000,
    input_length=100
)(input)

x = tf.keras.layers.LSTM(32)(x)

x = tf.keras.layers.Dense(64, activation="relu")(x)
x = tf.keras.layers.Dense(64, activation="relu")(x)
x = tf.keras.layers.Dense(64, activation="relu")(x)

output = tf.keras.layers.Dense(1, activation="sigmoid", name="output")(x)

model = tf.keras.Model(
    inputs=[input],
    outputs=[output]
)

dot_img_file = "models/xest_model.png"
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# %%
my_model = Sequential()
my_model.add(LSTM(4, batch_input_shape=(1, 1, 1), stateful=True))
my_model.add(Dense(1))
# my_model.compile(loss='mean_squared_error', optimizer='adam')
# for i in range(nb_epoch):
#     my_model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
#     my_model.reset_states()
my_dot_img_file = "models/my_model.png"
tf.keras.utils.plot_model(my_model, to_file=my_dot_img_file, show_shapes=True)

# %%
mymodel
